# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d1 = np.random.normal(0,1,1000)
plt.hist(d1,bins=20,color="#101249",alpha=0.7)
plt.title("Histogram")
plt.xlabel('Values')
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# KDE plot - kernel desnsity plot
sns.kdeplot(d1,color="#101249")
plt.title('KDE plot for dummy values')
plt.xlabel('Values')
plt.grid()
plt.show()

# %%
# KDE plot with histogram
d1 = np.random.normal(0,1,1000)
plt.hist(d1,bins=20,color="#101249",alpha=0.7,density=True)
sns.kdeplot(d1,color="#003366")
plt.title("Histogram")
plt.xlabel('Values')
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
plt.boxplot(d1)
plt.title("Dummy Box Plot")
plt.ylabel('Values')
plt.grid(True)
plt.show()

# %%
# Box Plot
data = [np.random.normal(0,1,1000) for i in range(5)]

data[0] += 5
data[3] -= 6

plt.boxplot(data,tick_labels = ["G1","G2","G3","G4","G5"])
plt.title("Box Plot of the Dummy Data")
plt.ylabel("Values")
plt.grid(True)
plt.show()

# %%
import kagglehub
import pandas as pd

# Download latest version
path = kagglehub.dataset_download("jayapriyadatascience/wineqt-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/mukundanramesh/.cache/kagglehub/datasets/jayapriyadatascience/wineqt-dataset/versions/1

# %%
import os
file_path = os.path.join(path,"WineQT.csv")
print(file_path)
# Out:
# /Users/mukundanramesh/.cache/kagglehub/datasets/jayapriyadatascience/wineqt-dataset/versions/1/WineQT.csv

# %%
wine_df = pd.read_csv(file_path)
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
wine_df.drop('Id',axis=1,inplace=True)
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
plt.figure(figsize=(12,10))

#wine_df = wine_df.drop(columns="Id")

sns.violinplot(data = wine_df)
plt.show()

# %%
#pie chart
sizes = [40, 30, 20, 10]
labels = ['Apples', 'Bananas', 'Cherries', 'Dates']
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']
explode = (0.1, 0, 0, 0)  # "explode" the 1st slice (Apples)

# Create the pie chart
plt.pie(sizes, 
        explode=explode, 
        labels=labels, 
        colors=colors, 
        autopct='%1.1f%%', 
        shadow=True, 
        startangle=140)

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')  

# Add a title and display
plt.title("Fruit Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create plot
fig, ax = plt.subplots()
ax.plot(x, y)

# 1. Set explicit axis limits
ax.set_xlim(0, 10)
ax.set_ylim(-1.5, 1.5)

# 2. Define custom tick locations
ax.set_xticks([0, 2.5, 5, 7.5, 10])

# 3. Apply custom text labels over those locations
ax.set_xticklabels(['Start', 'Quarter', 'Half', 'Three-Qtr', 'End'])

plt.show()

# %%
item_label = ["A","B","C","D","E"]
item_sold = [10,20,30,40,50]
plt.pie(item_sold,labels=item_label,autopct=lambda p: '{:.0f}'.format(p * sum(item_sold) / 100))
#plt.pie(item_sold,labels=item_label,autopct="%1.1f%%")
plt.show()

# %%
plt.bar(item_label,item_sold)
plt.show()

# %%
#Stacked Bar Plot
item_label = ["A","B","C","D","E"]
item_sold1 = [10,20,30,40,50]
item_sold2 = [5,60,50,40,70]
item_sold3 = [50,10,30,40,15]
item_sold4 = [50,100,24,36,1]
plt.figure(figsize=(12,10))
plt.bar(item_label,item_sold1,color ="#83819c",label="Store 1")
plt.bar(item_label,item_sold2,color="#494399",label="Store 2",bottom=item_sold1)
plt.bar(item_label,item_sold3,color="#867feb",label="Store 3",bottom=[i+j for i,j in zip(item_sold1,item_sold2)])
plt.bar(item_label,item_sold3,color="#09072e",label="Store 4",bottom=[i+j+k for i,j,k in zip(item_sold1,item_sold2,item_sold3)])
plt.xlabel("Stores")
plt.ylabel("Units Sold")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Your Data
item_label = ["A", "B", "C", "D", "E"]
item_sold1 = np.array([10, 20, 30, 40, 50])
item_sold2 = np.array([5, 60, 50, 40, 70])
item_sold3 = np.array([50, 10, 30, 40, 15])
item_sold4 = np.array([50, 100, 24, 36, 1])

# Calculate bottom baselines for stacking
stack1 = item_sold1
stack2 = stack1 + item_sold2
stack3 = stack2 + item_sold3
totals = stack3 + item_sold4  # Total height of each bar

fig, ax = plt.subplots(figsize=(10, 6))

# Plot each layer
b1 = ax.bar(item_label, item_sold1, label="Sold 1")
b2 = ax.bar(item_label, item_sold2, bottom=stack1, label="Sold 2")
b3 = ax.bar(item_label, item_sold3, bottom=stack2, label="Sold 3")
b4 = ax.bar(item_label, item_sold4, bottom=stack3, label="Sold 4")

# 1. Annotate individual segment values inside the bars
for bar_container in [b1, b2, b3, b4]:
    ax.bar_label(
        bar_container, 
        label_type="center", 
        color="white", 
        fontweight="bold", 
        fontsize=9
    )

# 2. Annotate the final cumulative total at the top edge of each bar
ax.bar_label(
    b4, 
    labels=[f"Total: {t}" for t in totals], 
    label_type="edge", 
    padding=5, 
    fontweight="bold", 
    color="black"
)

# Customise layout
ax.set_ylabel("Units Sold")
ax.set_title("Stacked Item Sales Breakdown")
ax.legend(loc="upper left")

# Expand y-axis limit slightly so top text does not get cut off
ax.set_ylim(0, max(totals) * 1.1)

plt.tight_layout()
plt.show()

# %%
item_label = ["A", "B","C","D","E"]
store_1 = [10, 20, 30, 40, 50]
store_2 = [20, 30, 40, 50, 60]
store_3 = [30, 40, 50, 60, 70]
store_4 = [40, 50, 60, 70, 80]


fig, ax = plt.subplots()

def _calculate(bar,lst):
    for rect, val in zip(bars,store_1):
      x_pos = rect.get_x() + rect.get_width() / 2
      y_pos = rect.get_y() + rect.get_height() / 2
      ax.annotate(f"{val}",(x_pos,y_pos),ha = "center",va = "center")
    

bars = ax.bar(item_label,store_1,color = "#cfc808",label = "Store 1")
bars2 = ax.bar(item_label,store_2,color = "#b0ace6",label = "Store 2",bottom=store_1)
bars3 = ax.bar(item_label,store_3,color = "#4287f5",label = "Store 3",bottom=[i+j for i,j in zip(store_1,store_2)])
bars4 = ax.bar(item_label,store_4,color = "#384559",label = "Store 4",bottom=[i+j+k for i,j,k in zip(store_1,store_2,store_3)])

"""for rect, val in zip(bars,store_1):
  x_pos = rect.get_x() + rect.get_width() / 2
  y_pos = rect.get_y() + rect.get_height() / 2
  ax.annotate(f"{val}",(x_pos,y_pos),ha = "center",va = "center")"""

def label_bars(bars, values):
    for rect, val in zip(bars, values):
        x_pos = rect.get_x() + rect.get_width() / 2
        y_pos = rect.get_y() + rect.get_height() / 2
        ax.annotate(f"{val}", (x_pos, y_pos), ha="center", va="center")

label_bars(bars, store_1)
label_bars(bars2, store_2)
label_bars(bars3, store_3)
label_bars(bars4, store_4)

plt.title("Stacked Bar Plot")
plt.xlabel("Items")
plt.ylabel("Sold Quantity")
plt.legend()
plt.show()

# %%
covid_data = pd.read_json('/Users/mukundanramesh/projects/ai_ml_course_bootcamp_practice/ai-ml-course-bootcamp/Visualization/covid_states_daily.json')
display(covid_data.head())
covid_data.info()
# Out:
#                                         states_daily
# 0  {'an': '0', 'ap': '1', 'ar': '0', 'as': '0', '...
# 1  {'an': '0', 'ap': '0', 'ar': '0', 'as': '0', '...
# 2  {'an': '0', 'ap': '0', 'ar': '0', 'as': '0', '...
# 3  {'an': '0', 'ap': '0', 'ar': '0', 'as': '0', '...
# 4  {'an': '0', 'ap': '0', 'ar': '0', 'as': '0', '...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1563 entries, 0 to 1562
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   states_daily  1563 non-null   object
# dtypes: object(1)
# memory usage: 12.3+ KB

# %%
covid_data.iloc[0]['states_daily']
# Out:
# {'an': '0',
#  'ap': '1',
#  'ar': '0',
#  'as': '0',
#  'br': '0',
#  'ch': '0',
#  'ct': '0',
#  'date': '14-Mar-20',
#  'dateymd': '2020-03-14',
#  'dd': '0',
#  'dl': '7',
#  'dn': '0',
#  'ga': '0',
#  'gj': '0',
#  'hp': '0',
#  'hr': '14',
#  'jh': '0',
#  'jk': '2',
#  'ka': '6',
#  'kl': '19',
#  'la': '0',
#  'ld': '0',
#  'mh': '14',
#  'ml': '0',
#  'mn': '0',
#  'mp': '0',
#  'mz': '0',
#  'nl': '0',
#  'or': '0',
#  'pb': '1',
#  'py': '0',
#  'rj': '3',
#  'sk': '0',
#  'status': 'Confirmed',
#  'tg': '1',
#  'tn': '1',
#  'tr': '0',
#  'tt': '81',
#  'un': '0',
#  'up': '12',
#  'ut': '0',
#  'wb': '0'}

# %%
import json
with open("/Users/mukundanramesh/projects/ai_ml_course_bootcamp_practice/ai-ml-course-bootcamp/Visualization/covid_states_daily.json","r") as file:
    data = json.load(file)
data = data["states_daily"]
df = pd.DataFrame(data)
df.status.value_counts()
# Out:
# status
# Confirmed    521
# Recovered    521
# Deceased     521
# Name: count, dtype: int64

# %%
g1 = df.groupby('status')
g1_data = list(g1)
for status,data in g1_data:
    print(status)
# Out:
# Confirmed
# Deceased
# Recovered

# %%
df_confirmed = g1_data[0][1]
df_recovered = g1_data[2][1]
df_deceased = g1_data[1][1]

df_deceased.head()
# Out:
#    an ap ar as br ch ct       date     dateymd dd  ... sk    status tg tn tr  \
# 2   0  0  0  0  0  0  0  14-Mar-20  2020-03-14  0  ...  0  Deceased  0  0  0
# 5   0  0  0  0  0  0  0  15-Mar-20  2020-03-15  0  ...  0  Deceased  0  0  0
# 8   0  0  0  0  0  0  0  16-Mar-20  2020-03-16  0  ...  0  Deceased  0  0  0
# 11  0  0  0  0  0  0  0  17-Mar-20  2020-03-17  0  ...  0  Deceased  0  0  0
# 14  0  0  0  0  0  0  0  18-Mar-20  2020-03-18  0  ...  0  Deceased  0  0  0
#
#    tt un up ut wb
# 2   2  0  0  0  0
# 5   0  0  0  0  0
# 8   0  0  0  0  0
# 11  1  0  0  0  0
# 14  0  0  0  0  0
#
# [5 rows x 42 columns]

# %%
df_confirmed.drop(columns=["status",'date'],inplace=True)
df_recovered.drop(columns=["status",'date'],inplace=True)
df_deceased.drop(columns=["status",'date'],inplace=True)

# %%
df_confirmed['dateymd'] =  pd.to_datetime(df_confirmed['dateymd'])
df_recovered['dateymd'] =  pd.to_datetime(df_confirmed['dateymd'])
df_deceased['dateymd'] =  pd.to_datetime(df_confirmed['dateymd'])
df_confirmed = df_confirmed.apply(pd.to_numeric)
df_recovered = df_recovered.apply(pd.to_numeric)
df_deceased = df_deceased.apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1563 entries, 0 to 1562
# Data columns (total 42 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   an       1563 non-null   object
#  1   ap       1563 non-null   object
#  2   ar       1563 non-null   object
#  3   as       1563 non-null   object
#  4   br       1563 non-null   object
#  5   ch       1563 non-null   object
#  6   ct       1563 non-null   object
#  7   date     1563 non-null   object
#  8   dateymd  1563 non-null   object
#  9   dd       1563 non-null   object
#  10  dl       1563 non-null   object
#  11  dn       1563 non-null   object
#  12  ga       1563 non-null   object
#  13  gj       1563 non-null   object
#  14  hp       1563 non-null   object
#  15  hr       1563 non-null   object
#  16  jh       1563 non-null   object
#  17  jk       1563 non-null   object
#  18  ka       1563 non-null   object
#  19  kl       1563 non-null   object
# ...

# %%
df_confirmed = df_confirmed.set_index("dateymd")
df_deceased = df_deceased.set_index("dateymd")
df_recovered = df_recovered.set_index("dateymd")

df_confirmed.index = pd.to_datetime(df_confirmed.index)
df_deceased.index = pd.to_datetime(df_deceased.index)
df_recovered.index = pd.to_datetime(df_recovered.index)

df_confirmed = df_confirmed.apply(pd.to_numeric)
df_deceased = df_deceased.apply(pd.to_numeric)
df_recovered = df_recovered.apply(pd.to_numeric)

df_confirmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 521 entries, 2020-03-14 to 2021-08-16
# Data columns (total 39 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   an      521 non-null    int64
#  1   ap      521 non-null    int64
#  2   ar      521 non-null    int64
#  3   as      521 non-null    int64
#  4   br      521 non-null    int64
#  5   ch      521 non-null    int64
#  6   ct      521 non-null    int64
#  7   dd      521 non-null    int64
#  8   dl      521 non-null    int64
#  9   dn      521 non-null    int64
#  10  ga      521 non-null    int64
#  11  gj      521 non-null    int64
#  12  hp      521 non-null    int64
#  13  hr      521 non-null    int64
#  14  jh      521 non-null    int64
#  15  jk      521 non-null    int64
#  16  ka      521 non-null    int64
#  17  kl      521 non-null    int64
#  18  la      521 non-null    int64
#  19  ld      521 non-null    int64
#  20  mh      521 non-null    int64
# ...

# %%
#Plot the graph for confirmed cases
data = df_confirmed.index
values = df_confirmed["ka"].values

plt.figure(figsize=(12,6))

plt.plot(data,values,color = "#a34567")
plt.title("Confirmed Cases in Karnataka")
plt.xlabel("Date")
plt.ylabel("Confirmed Cases")
plt.show()

# %%
#Plot the graph for confirmed cases
data = df_confirmed.index
values = df_confirmed["ap"].values

plt.figure(figsize=(12,6))

plt.plot(data,values,color = "#a34567")
plt.title("Confirmed Cases in Andhra Pradesh")
plt.xlabel("Date")
plt.ylabel("Confirmed Cases")
plt.show()

# %%
#subplots
# Subplots
x = np.linspace(0,10,100)
y1 = np.sin(x)
y2 = np.cos(x)


fig , axes = plt.subplots(nrows = 1, ncols = 2,figsize = (12,10))

axes[0].plot(x,y1,color = "#a34567")
axes[0].set_title("Sine Wave")
axes[0].set_xlabel("X-axis")
axes[0].set_ylabel("Y-axis")

axes[1].plot(x,y2,color = "#a34567")
axes[1].set_title("Cosine Wave")
axes[1].set_xlabel("X-axis")
axes[1].set_ylabel("Y-axis")

plt.show()

# %%
# super imposition of 2 plts in one plot

line = plt.plot(x,y1,color = "#a34567",label = "Sine Wave")
plt.plot(x,y2,color = "#a45517",label = "Cosine Wave")

plt.title("Sine and Cosine Wave")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()
