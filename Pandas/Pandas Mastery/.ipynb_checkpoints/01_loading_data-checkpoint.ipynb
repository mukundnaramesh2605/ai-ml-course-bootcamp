# %%
import pandas as pd

# %%
#Create Data Without a File

data = {
    "Name": ["Bob", "Martin", "Rahul"],
    "Age": [30, 28, 25],
    "City": ["Chennai", "Chennai", "Bangalore"]
}

df = pd.DataFrame(data)

df
# Out:
#      Name  Age       City
# 0     Bob   30    Chennai
# 1  Martin   28    Chennai
# 2   Rahul   25  Bangalore

# %%
#Understanding DataFrame
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv("/Users/mukundanramesh/projects/ai_ml_course_bootcamp_practice/ai-ml-course-bootcamp/Pandas/Pandas Mastery/Datasets/employees.csv")
df.head()
# Out:
#          EmployeeID   Name
# 1 Bob            QA  70000
# 2 Martin         HR  65000
# 3 Rahul   Developer  90000
# 4 Priya          QA  75000
# 5 Arun    Developer  95000

# %%
df.tail()
# Out:
#          EmployeeID   Name
# 1 Bob            QA  70000
# 2 Martin         HR  65000
# 3 Rahul   Developer  90000
# 4 Priya          QA  75000
# 5 Arun    Developer  95000

# %%
#Dataset Dimensions
df.shape
# Out:
# (5, 2)

# %%
#Column Names
df.columns
# Out:
# Index(['EmployeeID', 'Name'], dtype='object')

# %%
list(df.columns)
# Out:
# ['EmployeeID', 'Name']
