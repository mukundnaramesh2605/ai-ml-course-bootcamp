# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'/Users/mukundanramesh/projects/ai_ml_course_bootcamp_practice/ai-ml-course-bootcamp/Pandas/datasets/global_ev_adoption_behavior_2026.csv')
df.head()
# Out:
#    age  annual_income education_level city_type  daily_commute_km  \
# 0   56        23019.0     High School  Suburban              39.8
# 1   46        26440.0     High School  Suburban              34.6
# 2   46        57167.0             PhD  Suburban              30.5
# 3   23        15841.0          Master  Suburban              44.6
# 4   50        51571.0          Master     Urban              52.4
#
#    weekly_travel_distance_km current_vehicle_type  vehicle_age_years  \
# 0                      205.7            Hatchback                6.1
# 1                      218.4                Sedan                4.4
# 2                      177.7                Sedan                0.4
# 3                      325.9                  SUV                0.0
# 4                      281.0                  SUV                5.2
#
#    fuel_expense_per_month  charging_station_accessibility  ...  \
# 0                   317.1                             3.9  ...
# ...

# %%
#Use .loc[] to select rows 10–15 (inclusive) and only the columns age, annual_income, city_type.
df.loc[10:15]
# Out:
#     age  annual_income education_level city_type  daily_commute_km  \
# 10   46        67343.0          Master  Suburban              18.8
# 11   42        27271.0        Bachelor     Urban              31.4
# 12   43        28828.0        Bachelor  Suburban              47.8
# 13   30        56928.0          Master     Rural              44.0
# 14   32        86553.0     High School     Urban              41.7
# 15   57        20054.0     High School  Suburban              16.7
#
#     weekly_travel_distance_km current_vehicle_type  vehicle_age_years  \
# 10                      133.6                  SUV                8.7
# 11                      160.8            Hatchback                3.3
# 12                      247.3                Truck                1.4
# 13                      254.4                Sedan                6.0
# 14                      220.3            Hatchback                5.4
# 15                      120.5                Sedan                7.9
#
# ...

# %%
#Use .iloc[] to select the first 5 rows and the first 3 columns.
df.iloc[:5,:3]
# Out:
#    age  annual_income education_level
# 0   56        23019.0     High School
# 1   46        26440.0     High School
# 2   46        57167.0             PhD
# 3   23        15841.0          Master
# 4   50        51571.0          Master

# %%
#Use .loc[] with .between() to select all rows where age is between 25 and 35.
df.loc[df.age.between(25,35)]
# Out:
#        age  annual_income education_level city_type  daily_commute_km  \
# 13      30        56928.0          Master     Rural              44.0
# 14      32        86553.0     High School     Urban              41.7
# 20      26        46292.0        Bachelor  Suburban              53.6
# 24      34        43948.0        Bachelor     Urban              23.4
# 33      33        43493.0        Bachelor     Urban              32.5
# ...    ...            ...             ...       ...               ...
# 49987   29        20464.0          Master     Urban               7.4
# 49993   27        92400.0        Bachelor  Suburban              16.6
# 49994   29        80965.0     High School     Rural              39.7
# 49995   27        26296.0        Bachelor     Urban              37.4
# 49997   30        20862.0          Master  Suburban              37.5
#
#        weekly_travel_distance_km current_vehicle_type  vehicle_age_years  \
# ...

# %%
#4. Check whether there are any fully duplicated rows using .duplicated().
df=pd.concat((df,df.copy()),axis=0)
df[df.duplicated()]
# Out:
#        age  annual_income education_level city_type  daily_commute_km  \
# 0       56        23019.0     High School  Suburban              39.8
# 1       46        26440.0     High School  Suburban              34.6
# 2       46        57167.0             PhD  Suburban              30.5
# 3       23        15841.0          Master  Suburban              44.6
# 4       50        51571.0          Master     Urban              52.4
# ...    ...            ...             ...       ...               ...
# 49995   27        26296.0        Bachelor     Urban              37.4
# 49996   39        35476.0          Master  Suburban              30.5
# 49997   30        20862.0          Master  Suburban              37.5
# 49998   68        14694.0        Bachelor     Rural              40.3
# 49999   48        28828.0        Bachelor  Suburban              28.5
#
#        weekly_travel_distance_km current_vehicle_type  vehicle_age_years  \
# ...

# %%
#5. If duplicates exist, drop them with .drop_duplicates() and report the new row count. If .duplicated().sum() is 0, explain why that makes sense for this dataset.
df=df.drop_duplicates()
print(f"There are {df.duplicated().sum()} in this data sense and this makes sense because it means the dataset has no exact row duplicates. This makes sense if the data inherently represents unique, independent events and features a strict primary key or timestamp.")
# Out:
# There are 0 in this data sense and this makes sense because it means the dataset has no exact row duplicates. This makes sense if the data inherently represents unique, independent events and features a strict primary key or timestamp.

# %%
#6. Create a new column commute_to_travel_ratio = daily_commute_km / weekly_travel_distance_km.
df["commute_to_travel_ratio"] = df.daily_commute_km / df.weekly_travel_distance_km
df.commute_to_travel_ratio.head()
# Out:
# 0    0.193486
# 1    0.158425
# 2    0.171638
# 3    0.136852
# 4    0.186477
# Name: commute_to_travel_ratio, dtype: float64

# %%
#7. What is the average value of this new ratio column(commute_to_travel_ratio)?
print(f"The average value of commute_to_travel_ratio is {df.commute_to_travel_ratio.mean()}")
# Out:
# The average value of commute_to_travel_ratio is 0.15655838853633144

# %%
#8. Round annual_income to the nearest thousand and store it in a new column income_rounded.
df["income_rounded"] = df.annual_income.round(-3)
df[["annual_income","income_rounded"]].head()
# Out:
#    annual_income  income_rounded
# 0        23019.0         23000.0
# 1        26440.0         26000.0
# 2        57167.0         57000.0
# 3        15841.0         16000.0
# 4        51571.0         52000.0

# %%
#9. What is the .mode() of current_vehicle_type — the single most common vehicle type?
df.current_vehicle_type.mode()
# Out:
# 0    Sedan
# Name: current_vehicle_type, dtype: object

# %%
#10. Use .min() and .max() together on age to get the age range in one line.
df.age.agg([min,max])
# Out:
# /var/folders/lv/p9vlph914d5554g_z5tcrsdm0000gn/T/ipykernel_46916/455887465.py:2: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.age.agg([min,max])
# /var/folders/lv/p9vlph914d5554g_z5tcrsdm0000gn/T/ipykernel_46916/455887465.py:2: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.age.agg([min,max])
# min    21
# max    69
# Name: age, dtype: int64

# %%
#11. Are there any rows where fuel_expense_per_month is negative? Use .any() on a boolean condition to check in one line
has_negative = (df["fuel_expense_per_month"] < 0).any()
has_negative
# Out:
# np.True_

# %%
#12. How many columns in the dataframe are entirely numeric? Use select_dtypes().
numeric_cols_count = len(df.select_dtypes(include='number').columns)
print(numeric_cols_count)
# Out:
# 21

# %%
#13. On a copy of the dataframe, set city_type as the index using .set_index(). What changes about how the dataframe looks?
new_df = df.copy()
new_df = new_df.set_index("city_type")
new_df.head()
# Out:
#            age  annual_income education_level  daily_commute_km  \
# city_type
# Suburban    56        23019.0     High School              39.8
# Suburban    46        26440.0     High School              34.6
# Suburban    46        57167.0             PhD              30.5
# Suburban    23        15841.0          Master              44.6
# Urban       50        51571.0          Master              52.4
#
#            weekly_travel_distance_km current_vehicle_type  vehicle_age_years  \
# city_type
# Suburban                       205.7            Hatchback                6.1
# Suburban                       218.4                Sedan                4.4
# Suburban                       177.7                Sedan                0.4
# Suburban                       325.9                  SUV                0.0
# Urban                          281.0                  SUV                5.2
#
#            fuel_expense_per_month  charging_station_accessibility  \
# city_type
# ...

# %%
#14. Reset that index back to default using .reset_index().
new_df = new_df.reset_index()
new_df.head()
# Out:
#   city_type  age  annual_income education_level  daily_commute_km  \
# 0  Suburban   56        23019.0     High School              39.8
# 1  Suburban   46        26440.0     High School              34.6
# 2  Suburban   46        57167.0             PhD              30.5
# 3  Suburban   23        15841.0          Master              44.6
# 4     Urban   50        51571.0          Master              52.4
#
#    weekly_travel_distance_km current_vehicle_type  vehicle_age_years  \
# 0                      205.7            Hatchback                6.1
# 1                      218.4                Sedan                4.4
# 2                      177.7                Sedan                0.4
# 3                      325.9                  SUV                0.0
# 4                      281.0                  SUV                5.2
#
#    fuel_expense_per_month  charging_station_accessibility  ...  \
# 0                   317.1                             3.9  ...
# ...

# %%
#16. Use .sample(5) to randomly pick 5 rows. Run the cell twice — do you get the same rows both times?
df.sample(5)
# Out:
#        age  annual_income education_level city_type  daily_commute_km  \
# 45316   41        23742.0        Bachelor  Suburban              13.4
# 32378   50        12697.0     High School     Rural              25.5
# 29405   56        32293.0     High School  Suburban              18.1
# 45908   30        29360.0        Bachelor  Suburban              39.6
# 32614   31        31803.0        Bachelor  Suburban              38.8
#
#        weekly_travel_distance_km current_vehicle_type  vehicle_age_years  \
# 45316                       69.6            Hatchback                9.8
# 32378                      171.2            Hatchback                5.1
# 29405                      138.3                Sedan                3.0
# 45908                      204.8                  SUV                5.7
# 32614                      294.6            Hatchback               11.6
#
#        fuel_expense_per_month  charging_station_accessibility  ...  \
# ...

# %%
#17. Now use .sample(5, random_state=42). Run it twice — are the rows identical now? Why does that happen?
print(df.sample(5, random_state=42))
print('This happens because random_state=42 sets a seed for the pseudo-random number generator. By fixing this seed, the sequence of "random" numbers generated is locked in, making the sampling operation reproducible across multiple runs.')
# Out:
#        age  annual_income education_level city_type  daily_commute_km  \
# 33553   67        35013.0          Master  Suburban              46.0
# 9427    49        43084.0          Master  Suburban              31.5
# 199     22        10380.0        Bachelor     Urban              16.7
# 12447   69        63274.0        Bachelor  Suburban              37.3
# 39489   58        25859.0          Master     Urban              16.5
#
#        weekly_travel_distance_km current_vehicle_type  vehicle_age_years  \
# 33553                      330.1                  SUV                6.8
# 9427                       223.9                  SUV                4.9
# 199                         85.5                  SUV               11.1
# 12447                      264.7                Sedan                5.9
# 39489                       97.5                Sedan                3.7
#
#        fuel_expense_per_month  charging_station_accessibility  ...  \
# ...

# %%
#18. Use .clip(lower=0) on fuel_expense_per_month to fix any negative values. How many rows actually changed?
df.fuel_expense_per_month.clip(lower=0)
# Out:
# 0        317.1
# 1        290.0
# 2        201.4
# 3        407.3
# 4        458.4
#          ...
# 49995    314.8
# 49996    278.5
# 49997    358.4
# 49998    306.1
# 49999    227.5
# Name: fuel_expense_per_month, Length: 50000, dtype: float64

# %%
original = df['fuel_expense_per_month']
clipped = df['fuel_expense_per_month'].clip(lower=0)
original.sum(),clipped.sum()
# Out:
# (np.float64(14758480.399999999), np.float64(14763631.600000001))
