# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/mukundanramesh/projects/ai_ml_course_bootcamp_practice/ai-ml-course-bootcamp/Pandas'

# %%
df = pd.read_csv(r"datasets/Pandas - Q1 Sales.csv")

# %%
df.head(7)
# Out:
#      Country Region Sales Person    Date of Purchase    Total  Quantity
# 0      India  North         John  10/29/2018 0:00:00   100000       567
# 1         US  North         Bill   7/27/2011 0:00:00   120000      3000
# 2         UK  North       Thomas    7/6/2018 0:00:00   140000       345
# 3  Australia   East         John  12/16/2017 0:00:00   160000      1000
# 4     Africa   East         Bill   4/13/2017 0:00:00   180000       123
# 5  Singapore   East       Thomas   1/28/2012 0:00:00   200000      1000
# 6    Mylasia   West         John    2/2/2013 0:00:00  1000000      7890

# %%
df.tail(10)
# Out:
#       Country Region Sales Person    Date of Purchase   Total  Quantity
# 10  Australia  North         Bill  12/21/2018 0:00:00  120000       567
# 11     Africa  North       Thomas   9/19/2014 0:00:00  140000      1000
# 12  Singapore   East         John   5/23/2014 0:00:00  160000       892
# 13    Mylasia   East         Bill  10/31/2013 0:00:00  180000       444
# 14      India   East       Thomas  11/17/2016 0:00:00  200000        90
# 15         US   West         John   8/19/2017 0:00:00  220000        90
# 16         UK   West         Bill   11/8/2013 0:00:00  240000        90
# 17  Australia   West       Thomas    2/9/2011 0:00:00  260000        90
# 18     Africa  North         John    2/2/2017 0:00:00  140000        85
# 19  Singapore  North         Bill    7/1/2010 0:00:00  150000        85

# %%
print(df.describe())
# Out:
#               Total     Quantity
# count  2.000000e+01    20.000000
# mean   1.502500e+06   977.900000
# std    5.769280e+06  1761.923497
# min    1.000000e+05    85.000000
# 25%    1.400000e+05    90.000000
# 50%    1.700000e+05   505.500000
# 75%    2.250000e+05  1000.000000
# max    2.600000e+07  7890.000000

# %%
df[['Country','Region']]
# Out:
#       Country Region
# 0       India  North
# 1          US  North
# 2          UK  North
# 3   Australia   East
# 4      Africa   East
# 5   Singapore   East
# 6     Mylasia   West
# 7       India   West
# 8          US   West
# 9          UK  North
# 10  Australia  North
# 11     Africa  North
# 12  Singapore   East
# 13    Mylasia   East
# 14      India   East
# 15         US   West
# 16         UK   West
# 17  Australia   West
# 18     Africa  North
# 19  Singapore  North

# %%
df.iloc[0:3]
# Out:
#   Country Region Sales Person    Date of Purchase   Total  Quantity
# 0   India  North         John  10/29/2018 0:00:00  100000       567
# 1      US  North         Bill   7/27/2011 0:00:00  120000      3000
# 2      UK  North       Thomas    7/6/2018 0:00:00  140000       345

# %%
df[(df["Country"] == "India") & (df["Quantity"] > 90)]
# Out:
#   Country Region Sales Person    Date of Purchase   Total  Quantity
# 0   India  North         John  10/29/2018 0:00:00  100000       567
# 7   India   West         Bill   7/11/2018 0:00:00  240000       200

# %%
call_made = [10] * 20

# %%
df["Call_made"] = call_made

# %%
df.head()
# Out:
#      Country Region Sales Person    Date of Purchase   Total  Quantity  \
# 0      India  North         John  10/29/2018 0:00:00  100000       567
# 1         US  North         Bill   7/27/2011 0:00:00  120000      3000
# 2         UK  North       Thomas    7/6/2018 0:00:00  140000       345
# 3  Australia   East         John  12/16/2017 0:00:00  160000      1000
# 4     Africa   East         Bill   4/13/2017 0:00:00  180000       123
#
#    Call_made
# 0         10
# 1         10
# 2         10
# 3         10
# 4         10

# %%
row = ['India','South','Jim','4/13/2018 0:00:00','160000','234','60']

# %%
new_row = pd.DataFrame([row],columns=df.columns.values)

# %%
sales_df = pd.concat([df, new_row], ignore_index=True)

# %%
df.tail(2)
# Out:
#       Country Region Sales Person   Date of Purchase   Total Quantity  \
# 19  Singapore  North         Bill   7/1/2010 0:00:00  150000       85
# 20      India  South          Jim  4/13/2018 0:00:00  160000      234
#
#    Call_made
# 19        10
# 20        60

# %%
po_numbers = [int(f"1000{i}") for i in range(20)]
import random
random.shuffle(po_numbers)
po_numbers
# Out:
# [100015,
#  100012,
#  100016,
#  100017,
#  100011,
#  100019,
#  10002,
#  10004,
#  10006,
#  10009,
#  10003,
#  10008,
#  100014,
#  10005,
#  10007,
#  100013,
#  10001,
#  10000,
#  100010,
#  100018]

# %%
df["PO_Numbers"] = po_numbers
df.set_index("PO_Numbers",inplace=True)
df.head()
# Out:
#               Country Region Sales Person    Date of Purchase   Total  \
# PO_Numbers
# 100015          India  North         John  10/29/2018 0:00:00  100000
# 100012             US  North         Bill   7/27/2011 0:00:00  120000
# 100016             UK  North       Thomas    7/6/2018 0:00:00  140000
# 100017      Australia   East         John  12/16/2017 0:00:00  160000
# 100011         Africa   East         Bill   4/13/2017 0:00:00  180000
#
#             Quantity
# PO_Numbers
# 100015           567
# 100012          3000
# 100016           345
# 100017          1000
# 100011           123

# %%
df.sort_index(ascending=False)
# Out:
#               Country Region Sales Person    Date of Purchase     Total  \
# PO_Numbers
# 100019      Singapore   East       Thomas   1/28/2012 0:00:00    200000
# 100018      Singapore  North         Bill    7/1/2010 0:00:00    150000
# 100017      Australia   East         John  12/16/2017 0:00:00    160000
# 100016             UK  North       Thomas    7/6/2018 0:00:00    140000
# 100015          India  North         John  10/29/2018 0:00:00    100000
# 100014      Singapore   East         John   5/23/2014 0:00:00    160000
# 100013             US   West         John   8/19/2017 0:00:00    220000
# 100012             US  North         Bill   7/27/2011 0:00:00    120000
# 100011         Africa   East         Bill   4/13/2017 0:00:00    180000
# 100010         Africa  North         John    2/2/2017 0:00:00    140000
# 10009              UK  North         John   9/29/2018 0:00:00    100000
# 10008          Africa  North       Thomas   9/19/2014 0:00:00    140000
# 10007           India   East       Thomas  11/17/2016 0:00:00    200000
# 10006              US   West       Thomas    3/9/2013 0:00:00  26000000
# 10005         Mylasia   East         Bill  10/31/2013 0:00:00    180000
# 10004           India   West         Bill   7/11/2018 0:00:00    240000
# 10003       Australia  North         Bill  12/21/2018 0:00:00    120000
# 10002         Mylasia   West         John    2/2/2013 0:00:00   1000000
# 10001              UK   West         Bill   11/8/2013 0:00:00    240000
# 10000       Australia   West       Thomas    2/9/2011 0:00:00    260000
#
#             Quantity
# PO_Numbers
# 100019          1000
# 100018            85
# 100017          1000
# 100016           345
# 100015           567
# 100014           892
# 100013            90
# 100012          3000
# 100011           123
# 100010            85
# 10009           1000
# 10008           1000
# 10007             90
# 10006           1000
# 10005            444
# 10004            200
# 10003            567
# 10002           7890
# 10001             90
# 10000             90

# %%
df.sort_values(["Country","Region"],ascending=False, inplace=True)

# %%
df.head()
# Out:
#            Country Region Sales Person   Date of Purchase     Total  Quantity
# PO_Numbers
# 10006           US   West       Thomas   3/9/2013 0:00:00  26000000      1000
# 100013          US   West         John  8/19/2017 0:00:00    220000        90
# 100012          US  North         Bill  7/27/2011 0:00:00    120000      3000
# 10001           UK   West         Bill  11/8/2013 0:00:00    240000        90
# 100016          UK  North       Thomas   7/6/2018 0:00:00    140000       345

# %% [markdown]
# ### Date Time Handling

# %%
df["Date of Purchase"].iloc[0]
# Out:
# '3/9/2013 0:00:00'

# %%
type(df["Date of Purchase"].iloc[0])
# Out:
# str

# %%
pd.to_datetime(df["Date of Purchase"].iloc[0])
# Out:
# Timestamp('2013-03-09 00:00:00')

# %%
df["Date of Purchase"] = pd.to_datetime(df["Date of Purchase"])

# %%
df["Year"] = df["Date of Purchase"].dt.year

# %%
 df["Date of Purchase"].dt.minute
# Out:
# PO_Numbers
# 10006     0
# 100013    0
# 100012    0
# 10001     0
# 100016    0
# 10009     0
# 100018    0
# 100019    0
# 100014    0
# 10002     0
# 10005     0
# 10004     0
# 100015    0
# 10007     0
# 10000     0
# 10003     0
# 100017    0
# 10008     0
# 100010    0
# 100011    0
# Name: Date of Purchase, dtype: int32
