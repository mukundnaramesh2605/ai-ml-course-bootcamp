# %%
# YOLO

import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Using device:", device)

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch version: 2.14.0
# CUDA available: False
# Using device: cpu

# %%
import torch
import matplotlib.pyplot as plt

from ultralytics import YOLO
from PIL import Image

print("PyTorch:", torch.__version__)
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/mukundanramesh/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# PyTorch: 2.14.0

# %% [raw]
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/mukundanramesh/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# PyTorch: 2.14.0

# %%
model = YOLO("yolo11n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 10.9MB/s 0.5s.4s<0.1s

# %%
image = Image.open(r"Datatsets/bus.jpg")

plt.figure(figsize=(10, 8))
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
results = model.predict(
    source="Datatsets/bus.jpg",
    conf=0.25,
    device='cpu',
    verbose=False
)

# %%
result = results[0]

annotated_image = result.plot()

plt.figure(figsize=(12, 10))
plt.imshow(annotated_image[..., ::-1])
plt.axis("off")
plt.show()
