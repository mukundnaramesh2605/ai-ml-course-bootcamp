# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says Woof!")

d1 = Dog("Rex", 3)
d2 = Dog("Bella", 5)
d1.bark()
d2.bark()
# Out:
# Rex says Woof!
# Bella says Woof!

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return "Some sound"

class Cat(Animal):
    def speak(self):
        return f"{self.name} says Meow"

class Cow(Animal):
    def speak(self):
        return f"{self.name} says Moo"

print(Cat("Kitty").speak())
print(Cow("Lulu").speak())
# Out:
# Kitty says Meow
# Lulu says Moo

# %%
class Puppy(Dog,Animal):
    def __init__(self, name, age, owner):
        super().__init__(name, age)
        self.owner = owner

# %%
animals = [Cat("Kitty"), Cow("Lulu"),Puppy('Tiger',5,"Mu")]
for a in animals:
    print(a)
    print(a.speak())
# Out:
# ...
# Kitty says Meow
# ...
# Lulu says Moo
# ...
# Some sound

# %%
#Create a Rectangle class with width, height, and an area() method.
class Rectangle:
    def __init__(self,width,height):
        self.width = width
        self.height = height
    
    def area(self):
        return f"the area of rectangle is {self.width * self.height}"

class Square(Rectangle):
    def area(self):
        return f"The are of square is {self.width * self.width}"

display(Square(4,5).area())
display(Rectangle(width=4,height=5).area())
# Out:
# 'The are of square is 16'
# 'the area of rectangle is 20'

# %%
class shape:
    def area(self):
        return f"Some Area"
    class circle:
        def __init__(self,radius):
            self.radius = radius

        def area(self):
            return f"The are a of circel is {3.14 * (self.radius**2)}"
    class tirangle:
        def __init__(self,h,b):
            self.h = h
            self.b = b

        def area(self):
            return f"The area of the triangle is {(self.h*self.b)/2}"
        
areas = [shape.circle(5),shape,shape.tirangle(5,6)]
for a in areas:
    print(a.area())
# Out:
# The are a of circel is 78.5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 20
#      16             return f"The area of the triangle is {(self.h*self.b)/2}"
#      17
#      18 areas = [shape.circle(5),shape,shape.tirangle(5,6)]
#      19 for a in areas:
# ---> 20     print(a.area())
#
# TypeError: shape.area() missing 1 required positional argument: 'self'
