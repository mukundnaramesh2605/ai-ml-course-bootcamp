# %% [markdown]
# <a href="https://colab.research.google.com/github/mukundnaramesh2605/ai-ml-course-bootcamp/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jayapriyadatascience/wineqt-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|█████████████████████████████████████| 21.5k/21.5k [00:00<00:00, 14.0MB/s]
# Extracting files...
# Path to dataset files: /Users/mukundanramesh/.cache/kagglehub/datasets/jayapriyadatascience/wineqt-dataset/versions/1

# %%
import os
file_path = os.path.join(path, "WineQT.csv")

# %%
df = pd.read_csv(file_path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.loc[3]
# Out:
# fixed acidity           11.200
# volatile acidity         0.280
# citric acid              0.560
# residual sugar           1.900
# chlorides                0.075
# free sulfur dioxide     17.000
# total sulfur dioxide    60.000
# density                  0.998
# pH                       3.160
# sulphates                0.580
# alcohol                  9.800
# quality                  6.000
# Id                       3.000
# Name: 3, dtype: float64

# %%
df[6:9]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
#
#    alcohol  quality  Id
# 6      9.4        5   6
# 7     10.0        7   7
# 8      9.5        7   8

# %%
df.iloc[6]
# Out:
# fixed acidity            7.9000
# volatile acidity         0.6000
# citric acid              0.0600
# residual sugar           1.6000
# chlorides                0.0690
# free sulfur dioxide     15.0000
# total sulfur dioxide    59.0000
# density                  0.9964
# pH                       3.3000
# sulphates                0.4600
# alcohol                  9.4000
# quality                  5.0000
# Id                       6.0000
# Name: 6, dtype: float64

# %%
df[df['fixed acidity'] == df['fixed acidity'].min()]
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 32            4.6              0.52         0.15             2.1      0.054
#
#     free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 32                  8.0                  65.0   0.9934  3.9       0.56
#
#     alcohol  quality  Id
# 32     13.1        4  45

# %%
df.iloc[df['fixed acidity'].idxmin()]
# Out:
# fixed acidity            4.6000
# volatile acidity         0.5200
# citric acid              0.1500
# residual sugar           2.1000
# chlorides                0.0540
# free sulfur dioxide      8.0000
# total sulfur dioxide    65.0000
# density                  0.9934
# pH                       3.9000
# sulphates                0.5600
# alcohol                 13.1000
# quality                  4.0000
# Id                      45.0000
# Name: 32, dtype: float64
