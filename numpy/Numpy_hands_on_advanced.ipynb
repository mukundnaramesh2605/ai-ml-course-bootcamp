# %% [markdown]
# # Numpy Hands and Tutorial

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6])
print(arr,type(arr))
# Out:
# [1 2 3 4 5 6] <class 'numpy.ndarray'>

# %% [markdown]
# ## Mathematical Operations

# %%
print(arr +2)
# Out:
# [3 4 5 6 7 8]

# %%
print(arr -1)
# Out:
# [0 1 2 3 4 5]

# %%
print(arr * 8888)
# Out:
# [ 8888 17776 26664 35552 44440 53328]

# %%
print(arr /2)
# Out:
# [0.5 1.  1.5 2.  2.5 3. ]

# %%
print(arr // 2)
# Out:
# [0 1 1 2 2 3]

# %% [markdown]
# ## Shape and Dimension

# %%
arr.shape
# Out:
# (6,)

# %%
arr.ndim
# Out:
# 1

# %%
arr.dtype
# Out:
# dtype('int64')
