# %%
def _kwargs(**kwargs):
    print(kwargs['fname'])
    for k,v in kwargs.items():
        print(k,v)
_kwargs(fname="Mukundan",lname="Ramesh")
# Out:
# Mukundan
# fname Mukundan
# lname Ramesh

# %%
import pandas as pd

# %%
pd.merge()
